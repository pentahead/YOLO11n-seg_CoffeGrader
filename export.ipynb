# %%
#turn on venv_export
from ultralytics import YOLO

def main():
    model = YOLO("runs/segment/train13/weights/best.pt")

    model.export(format="tflite")
    
    # model.export(format="tflite", half=True) -- (PTQ FP16)

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.4.32  Python-3.11.3 torch-2.11.0+cpu CPU (AMD Ryzen 5 3600X 6-Core Processor)
# YOLO11s-seg summary (fused): 114 layers, 10,074,943 parameters, 0 gradients, 32.8 GFLOPs
#
# PyTorch: starting from 'runs\segment\train13\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 57, 8400), (1, 32, 160, 160)) (19.6 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.1...
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  2.3s, saved as 'runs\segment\train13\weights\best.onnx' (38.8 MB)
# WARNING:tensorflow:From c:\dhiya\venv_export\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'runs\segment\train13\weights\best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   List[TensorSpec(shape=(1, 57, 8400), dtype=tf.float32, name=None), TensorSpec(shape=(1, 160, 160, 32), dtype=tf.float32, name=None)]
# Captures:
#   1534425180944: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534425180752: TensorSpec(shape=(3, 3, 3, 32), dtype=tf.float32, name=None)
#   1534425181328: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534425182672: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534425184016: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   1534425183632: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534425184592: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1534425184976: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534425185168: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534425185360: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534423753808: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   1534423753424: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   1534425185552: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   1534425185936: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534425184784: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534425185744: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534425186128: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   1534458201488: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458201296: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534458200912: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534458201104: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458201680: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534458202064: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458202640: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458202448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458203408: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   1534458204752: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534458202256: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   1534458201872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458202832: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458203024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458204944: TensorSpec(shape=(1, 1, 192, 256), dtype=tf.float32, name=None)
#   1534458205136: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458204176: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534458203600: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   1534458203984: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458205328: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1534458205712: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458206288: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458206096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458207056: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1534458208400: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458208784: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534458208592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458205520: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534458207824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458209168: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534458209360: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458207632: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534458205904: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1534458209552: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458207248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534458210128: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534458209936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458206480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458206672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458210320: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1534458208976: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458210704: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534458210512: TensorSpec(shape=(3, 3, 256, 512), dtype=tf.float32, name=None)
#   1534458209744: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534458210896: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   1534458211280: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534458211856: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458211664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458212624: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1534458213968: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458214352: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534458214160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458211088: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534458213392: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458214736: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534458214928: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458213200: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534458211472: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1534458215120: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458212816: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534458215696: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1534458215504: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458212048: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458212240: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534458215888: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   1534458214544: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534458216080: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   1534458215312: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534458216272: TensorSpec(shape=(1, 1, 1024, 512), dtype=tf.float32, name=None)
#   1534518657104: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534518657296: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   1534518657680: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534518658256: TensorSpec(shape=(1, 1, 256, 512), dtype=tf.float32, name=None)
#   1534518657488: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534518659216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1534518657872: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518662672: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1534518662288: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518662096: TensorSpec(shape=(1, 1, 256, 512), dtype=tf.float32, name=None)
#   1534518662480: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534518661328: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   1534518661904: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518661520: TensorSpec(shape=(1, 1, 512, 512), dtype=tf.float32, name=None)
#   1534518661712: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534518663248: TensorSpec(shape=(1, 1, 768, 256), dtype=tf.float32, name=None)
#   1534518663056: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518663440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518663632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518664208: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   1534518665552: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534518660752: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   1534518658064: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518662864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518663824: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518665744: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1534518665936: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518664400: TensorSpec(shape=(1, 1, 512, 128), dtype=tf.float32, name=None)
#   1534518664976: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518666512: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518666320: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518667280: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   1534518668624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534518666128: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   1534518664784: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534518666704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518666896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534518668816: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   1534518669008: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518668048: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534518667472: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534518667856: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518671888: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1534518672464: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534662673808: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662673616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662674768: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   1534662674576: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662676688: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   1534662676112: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662674000: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662674192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662677648: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1534662678800: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534662678416: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1534662677840: TensorSpec(shape=(3, 3, 256, 256), dtype=tf.float32, name=None)
#   1534662677456: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534662679952: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   1534662680144: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534662681872: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662681680: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662684752: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1534662680912: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662685136: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534662685520: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662685712: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534662686288: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662687056: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534662684176: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662686672: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534662683024: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1534662686480: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662684944: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662686096: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1534662686864: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534662682256: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662682448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1534662687440: TensorSpec(shape=(1, 1, 768, 512), dtype=tf.float32, name=None)
#   1534662685904: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534662687248: TensorSpec(shape=(3, 3, 512, 64), dtype=tf.float32, name=None)
#   1534662675920: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   1534518669200: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   1534662682064: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662679184: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534518669392: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662688592: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534662672464: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534518671120: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1534662687632: TensorSpec(shape=(3, 3, 512, 1), dtype=tf.float32, name=None)
#   1534662678224: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   1534518669968: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   1534662688208: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662678608: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534518670736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662683408: TensorSpec(shape=(512,), dtype=tf.float32, name=None)
#   1534662676880: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1534518669584: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534792074256: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1534662680336: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1534518673040: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1534662684368: TensorSpec(shape=(1, 1, 512, 128), dtype=tf.float32, name=None)
#   1534662675152: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1534518671312: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534792073872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662680528: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534518673232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1534662688400: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662679376: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518670928: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534792074448: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   1534662681104: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   1534662672848: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   1534518669776: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534662688016: TensorSpec(shape=(3, 3, 512, 32), dtype=tf.float32, name=None)
#   1534662678992: TensorSpec(shape=(3, 3, 256, 32), dtype=tf.float32, name=None)
#   1534518670352: TensorSpec(shape=(3, 3, 128, 32), dtype=tf.float32, name=None)
#   1534792073680: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662680720: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662672656: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518670544: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662687824: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534662678032: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534518670160: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534792077136: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534662683600: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534662677264: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1534518672272: TensorSpec(shape=(2, 2, 128, 128), dtype=tf.float32, name=None)
#   1534792073296: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1534662679568: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1534518671504: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1534792075216: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662685328: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534662675344: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534792073488: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534662679760: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534518671696: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534423753040: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   1534518672848: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1534518672656: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1534518659408: TensorSpec(shape=(1, 1, 128, 21), dtype=tf.float32, name=None)
#   1534662682832: TensorSpec(shape=(1, 1, 128, 21), dtype=tf.float32, name=None)
#   1534662673424: TensorSpec(shape=(1, 1, 128, 21), dtype=tf.float32, name=None)
#   1534792074832: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1534662681488: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1534662673232: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1534518660176: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1534662684560: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1534662676496: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1534792074640: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534662681296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534662673040: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1534792076560: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1534792077328: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1534792075792: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1534792076944: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1534662676304: TensorSpec(shape=(1, 1, 128, 32), dtype=tf.float32, name=None)
#   1534261114448: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   1534261114640: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   1534662677072: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success  25.1s, saved as 'runs\segment\train13\weights\best_saved_model' (97.1 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.1...
# TensorFlow Lite: export success  0.0s, saved as 'runs\segment\train13\weights\best_saved_model\best_float32.tflite' (38.7 MB)
#
# Export complete (25.9s)
# Results saved to C:\dhiya\runs\segment\train13\weights
# Predict:         yolo predict task=segment model=runs\segment\train13\weights\best_saved_model\best_float32.tflite imgsz=640
# Validate:        yolo val task=segment model=runs\segment\train13\weights\best_saved_model\best_float32.tflite imgsz=640 data=cropped+original-robusta-dataset-1/data.yaml
# Visualize:       https://netron.app
