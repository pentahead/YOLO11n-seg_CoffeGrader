# %%
#turn on venv_export
from ultralytics import YOLO

def main():
    model = YOLO("runs/segment/runs/coffe-sni-clean-1/weights/best.pt")

    model.export(format="tflite")
    
    # model.export(format="tflite", half=True) -- (PTQ FP16)

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.4.32  Python-3.11.3 torch-2.11.0+cpu CPU (AMD Ryzen 5 3600X 6-Core Processor)
# YOLO11n-seg summary (fused): 114 layers, 2,836,713 parameters, 0 gradients, 9.6 GFLOPs
#
# PyTorch: starting from 'runs\segment\runs\coffe-sni-clean-1\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 47, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.1...
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  2.1s, saved as 'runs\segment\runs\coffe-sni-clean-1\weights\best.onnx' (11.2 MB)
# WARNING:tensorflow:From c:\dhiya\venv_export\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'runs\segment\runs\coffe-sni-clean-1\weights\best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   List[TensorSpec(shape=(1, 47, 8400), dtype=tf.float32, name=None), TensorSpec(shape=(1, 160, 160, 32), dtype=tf.float32, name=None)]
# Captures:
#   2296781187472: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296781187280: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   2296781187856: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2296781187664: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296781190544: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2296781190160: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296781191120: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2296781191504: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296781192080: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296781191696: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296777581264: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   2296777580880: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   2296781191888: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   2296781192848: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2296781191312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296781192272: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296781192656: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   2296781192464: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784274256: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296784274064: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296784274448: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784274640: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296784275024: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784275600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784275408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784276368: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   2296784277712: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2296784275216: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2296784274832: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784275792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784275984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784277904: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   2296784278096: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784277136: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296784276560: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   2296784276944: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784278288: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2296784278672: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784279248: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784279056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784280016: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2296784281360: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784281744: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296784281552: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784278480: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296784280784: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784282128: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296784282320: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784280592: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296784278864: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2296784282512: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784280208: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296784283088: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296784282896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784279440: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784279632: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784283280: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2296784281936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784283664: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296784283472: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   2296784282704: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296784283856: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2296784284240: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296784284816: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784284624: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784285584: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2296784286928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784287312: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296784287120: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784284048: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296784286352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784287696: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296784287888: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784286160: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296784284432: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2296784288080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784285776: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296784288656: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2296784288464: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784285008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784285200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296784288848: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2296784287504: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296784289040: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   2296784289232: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296784289424: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   2296784288272: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296784289616: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2296893538384: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296893539152: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   2296893538768: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296893540112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2296893538576: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893543568: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2296893543184: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893542992: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   2296893543376: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296893542224: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   2296893542800: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893542416: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2296893542608: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296893544144: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   2296893543952: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893544336: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893544528: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893545104: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2296893546448: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296893541648: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   2296893538960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893543760: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893544720: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893546640: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2296893546832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893545296: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   2296893545872: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893547408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893547216: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893548176: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   2296893549520: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2296893547024: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2296893545680: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296893547600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893547792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296893549712: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   2296893549904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893548944: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296893548368: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296893548752: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893552784: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2296893553360: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296896701456: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896701264: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896702416: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2296896702224: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296896704336: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   2296896703760: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896701648: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896701840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896705296: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2296896706448: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296896706064: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2296896705488: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   2296896705104: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296896707600: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2296896707792: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296896709520: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896709328: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896712400: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2296896708560: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896712784: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896713168: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896713360: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896713936: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896714704: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896711824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896714320: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896710672: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2296896714128: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896712592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896713744: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2296896714512: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296896709904: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896710096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2296896715088: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2296896713552: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296896714896: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   2296896703568: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   2296893550096: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896709712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896706832: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893550288: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896716240: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896700880: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296893552016: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896715280: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   2296896705872: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   2296893550864: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2296896715856: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896706256: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893551632: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896711056: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2296896704528: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2296893550480: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296914018960: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296896707984: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296893554512: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296896712016: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   2296896702800: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2296893552208: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296914018576: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896708176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893553936: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896716048: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896707024: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893551824: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296914019152: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2296896708752: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2296896700496: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2296893550672: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296896715664: TensorSpec(shape=(3, 3, 256, 32), dtype=tf.float32, name=None)
#   2296896706640: TensorSpec(shape=(3, 3, 128, 32), dtype=tf.float32, name=None)
#   2296893551248: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2296914018384: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896708368: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893554320: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893551440: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896715472: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296896705680: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296893551056: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296914021840: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296896711248: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296896704912: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2296893553168: TensorSpec(shape=(2, 2, 64, 64), dtype=tf.float32, name=None)
#   2296896716432: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296896707216: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296893552400: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2296914019920: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896712976: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896702992: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296896716624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296896707408: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296893552592: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296777580496: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   2296893553744: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2296893553552: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2296893540304: TensorSpec(shape=(1, 1, 64, 11), dtype=tf.float32, name=None)
#   2296896710480: TensorSpec(shape=(1, 1, 64, 11), dtype=tf.float32, name=None)
#   2296896701072: TensorSpec(shape=(1, 1, 64, 11), dtype=tf.float32, name=None)
#   2296914019536: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2296896709136: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2296893554128: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2296893541072: TensorSpec(shape=(11,), dtype=tf.float32, name=None)
#   2296896712208: TensorSpec(shape=(11,), dtype=tf.float32, name=None)
#   2296896704144: TensorSpec(shape=(11,), dtype=tf.float32, name=None)
#   2296914019344: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296896708944: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296896700688: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2296914021264: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2296914022032: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2296914020496: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2296914021648: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2296896703952: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2296668485008: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   2296668484816: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   2296896704720: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success  22.2s, saved as 'runs\segment\runs\coffe-sni-clean-1\weights\best_saved_model' (28.0 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.1...
# TensorFlow Lite: export success  0.0s, saved as 'runs\segment\runs\coffe-sni-clean-1\weights\best_saved_model\best_float32.tflite' (11.1 MB)
#
# Export complete (22.8s)
# Results saved to C:\dhiya\runs\segment\runs\coffe-sni-clean-1\weights
# Predict:         yolo predict task=segment model=runs\segment\runs\coffe-sni-clean-1\weights\best_saved_model\best_float32.tflite imgsz=640
# Validate:        yolo val task=segment model=runs\segment\runs\coffe-sni-clean-1\weights\best_saved_model\best_float32.tflite imgsz=640 data=coffe-sni-clean-1/data.yaml
# Visualize:       https://netron.app
