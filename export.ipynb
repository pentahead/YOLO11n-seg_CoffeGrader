# %%
#turn on venv_export
from ultralytics import YOLO

def main():
    model = YOLO("runs/segment/train10/weights/best.pt")

    model.export(format="tflite")
    
    # model.export(format="tflite", half=True) -- (PTQ FP16)

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.4.32  Python-3.11.3 torch-2.11.0+cpu CPU (AMD Ryzen 5 3600X 6-Core Processor)
# YOLO11n-seg summary (fused): 114 layers, 2,838,663 parameters, 0 gradients, 9.6 GFLOPs
#
# PyTorch: starting from 'runs\segment\train10\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 57, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.1...
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  2.0s, saved as 'runs\segment\train10\weights\best.onnx' (11.2 MB)
# WARNING:tensorflow:From c:\dhiya\venv_export\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'runs\segment\train10\weights\best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   List[TensorSpec(shape=(1, 57, 8400), dtype=tf.float32, name=None), TensorSpec(shape=(1, 160, 160, 32), dtype=tf.float32, name=None)]
# Captures:
#   1799928146512: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1799928146320: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   1799928146896: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   1799928146704: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1799928149584: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   1799928149200: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799928150160: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1799928150544: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799928151120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799928150736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799926702992: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   1799926702608: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   1799928150928: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   1799928151888: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   1799928150352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799928151312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799928151696: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   1799928151504: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933953040: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1799933952848: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1799933953232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933953424: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1799933953808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933954384: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933954192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933955152: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   1799933956496: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   1799933954000: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   1799933953616: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933954576: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933954768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933956688: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   1799933956880: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933955920: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1799933955344: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1799933955728: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933957072: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1799933957456: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933958032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933957840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933958800: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   1799933960144: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933960528: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1799933960336: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933957264: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1799933959568: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933960912: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1799933961104: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933959376: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1799933957648: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   1799933961296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933958992: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799933961872: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1799933961680: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933958224: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933958416: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933962064: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   1799933960720: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933962448: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1799933962256: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   1799933961488: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1799933962640: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1799933963024: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1799933963600: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933963408: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933964368: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1799933965712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933966096: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1799933965904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933962832: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1799933965136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933966480: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1799933966672: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933964944: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1799933963216: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1799933966864: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933964560: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1799933967440: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1799933967248: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933963792: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933963984: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1799933967632: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1799933966288: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1799933967824: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1799933968016: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1799933967056: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   1799933968208: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800043053136: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1800043053328: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800043054096: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   1800043053712: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800043055056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1800043053520: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043058512: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1800043058128: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043057936: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   1800043058320: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800043057168: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   1800043057744: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043057360: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   1800043057552: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800043059088: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   1800043058896: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043059280: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043059472: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043060048: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   1800043061392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800043056592: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   1800043053904: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043058704: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043059664: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043061584: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   1800043061776: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043060240: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   1800043060816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043062352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043062160: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043063120: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   1800043064464: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   1800043061968: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   1800043060624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800043062544: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043062736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800043064656: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   1800043064848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043063888: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1800043063312: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800043063696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043067728: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   1800043068304: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800046249168: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046248976: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046250128: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   1800046249936: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800046252048: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   1800046251472: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046249360: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046249552: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046253008: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   1800046254160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800046253776: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   1800046253200: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   1800046252816: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800046255312: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1800046255504: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800046257232: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046257040: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046260112: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1800046256272: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046260496: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046260880: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046261072: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046261648: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046262416: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046259536: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046262032: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046258384: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1800046261840: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046260304: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046261456: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   1800046262224: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800046257616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046257808: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   1800046262800: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   1800046261264: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800046262608: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   1800046251280: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   1800043065040: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046257424: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046254544: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043065232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046263952: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046248016: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800043066960: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046262992: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   1800046253584: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   1800043065808: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   1800046263568: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046253968: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043066576: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046258768: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   1800046252240: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   1800043065424: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800063288144: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800046255696: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800043068880: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800046259728: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   1800046250512: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   1800043067152: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800063287760: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046255888: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043069072: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046263760: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046254736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043066768: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800063288336: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   1800046256464: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   1800046248208: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   1800043065616: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800046263376: TensorSpec(shape=(3, 3, 256, 32), dtype=tf.float32, name=None)
#   1800046254352: TensorSpec(shape=(3, 3, 128, 32), dtype=tf.float32, name=None)
#   1800043066192: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   1800063287568: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046256080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043069264: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043066384: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046263184: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800046253392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800043066000: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800063291024: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800046258960: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800046252624: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   1800043068112: TensorSpec(shape=(2, 2, 64, 64), dtype=tf.float32, name=None)
#   1800046264144: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1800046254928: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1800043067344: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   1800063289104: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046260688: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800046250704: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800063287376: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800046255120: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800043067536: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1799926702224: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   1800043068688: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   1800043068496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   1800043055248: TensorSpec(shape=(1, 1, 64, 21), dtype=tf.float32, name=None)
#   1800046258192: TensorSpec(shape=(1, 1, 64, 21), dtype=tf.float32, name=None)
#   1800046248784: TensorSpec(shape=(1, 1, 64, 21), dtype=tf.float32, name=None)
#   1800063288720: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1800046256848: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1800046248592: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   1800043056016: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1800046259920: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1800046251856: TensorSpec(shape=(21,), dtype=tf.float32, name=None)
#   1800063288528: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800046256656: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800046248400: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   1800063290448: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1800063291216: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1800063289680: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1800063290832: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   1800046251664: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   1799817573968: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   1799817573776: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   1800046252432: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success  21.3s, saved as 'runs\segment\train10\weights\best_saved_model' (28.1 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.1...
# TensorFlow Lite: export success  0.0s, saved as 'runs\segment\train10\weights\best_saved_model\best_float32.tflite' (11.1 MB)
#
# Export complete (21.9s)
# Results saved to C:\dhiya\runs\segment\train10\weights
# Predict:         yolo predict task=segment model=runs\segment\train10\weights\best_saved_model\best_float32.tflite imgsz=640
# Validate:        yolo val task=segment model=runs\segment\train10\weights\best_saved_model\best_float32.tflite imgsz=640 data=primer-robusta_sni_dataset-2/data.yaml
# Visualize:       https://netron.app
