# %%
from ultralytics import YOLO

def main():
    model = YOLO("runs/segment/runs/coffee-seg-final/weights/best.pt")

    model.export(format="tflite")
    
    # model.export(format="tflite", half=True) -- (PTQ FP16)

if __name__ == "__main__":
    main()
# Out:
# Ultralytics 8.4.32  Python-3.11.3 torch-2.11.0+cpu CPU (AMD Ryzen 5 3600X 6-Core Processor)
# YOLO11n-seg summary (fused): 114 layers, 2,836,908 parameters, 0 gradients, 9.6 GFLOPs
#
# PyTorch: starting from 'runs\segment\runs\coffee-seg-final\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 48, 8400), (1, 32, 160, 160)) (5.7 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.1...
#
# ONNX: starting export with onnx 1.21.0 opset 20...
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  3.9s, saved as 'runs\segment\runs\coffee-seg-final\weights\best.onnx' (11.2 MB)
# WARNING:tensorflow:From d:\dhiya_skirpsi\model_YOLO11-seg\venv_export\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'runs\segment\runs\coffee-seg-final\weights\best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   List[TensorSpec(shape=(1, 48, 8400), dtype=tf.float32, name=None), TensorSpec(shape=(1, 160, 160, 32), dtype=tf.float32, name=None)]
# Captures:
#   2412441366800: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412441366608: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   2412441367184: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2412441368720: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412441369872: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2412441369488: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412441370448: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2412445581392: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445582160: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445581584: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412435919248: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   2412435918864: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   2412445583504: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   2412445583312: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2412445581776: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445582352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445582928: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   2412445584080: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445583696: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412445583888: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412445584272: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445584464: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412445584848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445585424: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445585232: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445586192: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   2412445587536: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2412445585040: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2412445584656: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445585616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445585808: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445587728: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   2412445587920: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412445586960: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412445586384: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   2412445586768: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412445588112: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2412445588496: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412445589072: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445588880: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445589840: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2412445591184: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445591568: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412445591376: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445588304: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412445590608: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445591952: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412445592144: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445590416: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412445588688: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2412445592336: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445590032: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412445592912: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412445592720: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445589264: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445589456: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445593104: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2412445591760: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412445593488: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412445593296: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   2412445592528: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412445593680: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2412445594064: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412445594640: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445594448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445595408: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2412445596752: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445597136: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412445596944: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445593872: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412445596176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445595984: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412445597328: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445597520: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412445594256: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2412505645136: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412445595600: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505645904: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2412505645712: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412445594832: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412445595024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505646096: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2412505645520: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505646288: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   2412505646480: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505646672: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   2412505645328: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505646864: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2412505647248: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505647824: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   2412505647056: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505648208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2412505649936: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505652624: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2412505652240: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505652048: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   2412505652432: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505650896: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   2412505651856: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505651472: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   2412505651664: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412505653200: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   2412505653008: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505653392: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505653584: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505654160: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2412505655504: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412505650704: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   2412505647440: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505652816: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505653776: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505655696: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2412505655888: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505654352: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   2412505654928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505656464: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505656272: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505657232: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   2412505658576: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   2412505656080: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   2412505654736: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412505656656: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505656848: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412505658768: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   2412505658960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505658000: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412505657424: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412505657808: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538840080: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2412538840272: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412538842576: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538842384: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538843536: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2412538843344: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538845456: TensorSpec(shape=(3, 3, 32, 64), dtype=tf.float32, name=None)
#   2412538844880: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538842768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538842960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538846416: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   2412538847568: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412538847184: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   2412538846608: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   2412538846224: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412538848720: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2412538848912: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412538850640: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538850448: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538853520: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2412538849680: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538853904: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538854288: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538854480: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538855248: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538854864: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538852944: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538852176: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538851792: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2412538850832: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538853712: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538853136: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   2412538854672: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412538851024: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538851216: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   2412538855056: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   2412541657360: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412541657552: TensorSpec(shape=(3, 3, 256, 64), dtype=tf.float32, name=None)
#   2412538844688: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   2412505659152: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412541657744: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538847952: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505659344: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412541659088: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538841040: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412505661072: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412541658128: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   2412538846992: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   2412505659920: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2412541658704: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538847376: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505660688: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412541657936: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   2412538845648: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   2412505659536: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505649360: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412538849104: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412538841424: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412541657168: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   2412538843920: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   2412505661264: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412505648592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538849296: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538840848: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412541658896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538848144: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505660880: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412435918288: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2412538849872: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2412538841616: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   2412505659728: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412541658512: TensorSpec(shape=(3, 3, 256, 32), dtype=tf.float32, name=None)
#   2412538847760: TensorSpec(shape=(3, 3, 128, 32), dtype=tf.float32, name=None)
#   2412505660304: TensorSpec(shape=(3, 3, 64, 32), dtype=tf.float32, name=None)
#   2412435920592: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538849488: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538841232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412505660496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412541658320: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538846800: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412505660112: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412308660048: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412538852368: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412538846032: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   2412538839888: TensorSpec(shape=(2, 2, 64, 64), dtype=tf.float32, name=None)
#   2412541659280: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412538848336: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412538839120: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   2412308658896: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538854096: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412538844112: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412541659472: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538848528: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538839312: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412358284112: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   2412538840656: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   2412538840464: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   2412358284304: TensorSpec(shape=(1, 1, 64, 12), dtype=tf.float32, name=None)
#   2412538851600: TensorSpec(shape=(1, 1, 64, 12), dtype=tf.float32, name=None)
#   2412538842192: TensorSpec(shape=(1, 1, 64, 12), dtype=tf.float32, name=None)
#   2412435918480: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2412538850256: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2412538842000: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   2412435916560: TensorSpec(shape=(12,), dtype=tf.float32, name=None)
#   2412538853328: TensorSpec(shape=(12,), dtype=tf.float32, name=None)
#   2412538845264: TensorSpec(shape=(12,), dtype=tf.float32, name=None)
#   2412435918096: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538850064: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412538841808: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   2412541659856: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2412541661776: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2412541660432: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2412541661584: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   2412538845072: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   2412541662352: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   2412541661968: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   2412538845840: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
# TensorFlow SavedModel: export success  48.1s, saved as 'runs\segment\runs\coffee-seg-final\weights\best_saved_model' (28.0 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.1...
# TensorFlow Lite: export success  0.0s, saved as 'runs\segment\runs\coffee-seg-final\weights\best_saved_model\best_float32.tflite' (11.1 MB)
#
# Export complete (51.0s)
# Results saved to D:\dhiya_skirpsi\model_YOLO11-seg\runs\segment\runs\coffee-seg-final\weights
# Predict:         yolo predict task=segment model=runs\segment\runs\coffee-seg-final\weights\best_saved_model\best_float32.tflite imgsz=640
# Validate:        yolo val task=segment model=runs\segment\runs\coffee-seg-final\weights\best_saved_model\best_float32.tflite imgsz=640 data=dataset/data.yaml
# Visualize:       https://netron.app
