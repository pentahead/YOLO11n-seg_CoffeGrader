# %%
# =========================
# CELL 2 — Download dataset dari Roboflow (YOLOv11 seg format)
# =========================
from roboflow import Roboflow

# 🔴 WAJIB: ganti sesuai akun Anda
API_KEY      = "3XqJ4JBxm0LlPhLMsr6Z"              # ← wajib diisi
WORKSPACE    = "faruq-reybi"
PROJECT_NAME = "coffee-beans-dataset-2-segmentation-f7xlx-f7ttr"
VERSION      = 2  # ganti sesuai versi dataset

rf      = Roboflow(api_key=API_KEY)
project = rf.workspace(WORKSPACE).project(PROJECT_NAME)
version = project.version(VERSION)
dataset = version.download("yolov11")


DATASET_PATH = dataset.location
print(f"✅ Dataset berhasil didownload ke: {DATASET_PATH}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to coffee-beans-dataset-2-(segmentation)-2 in yolov11:: 100%|██████████| 48720/48720 [03:28<00:00, 233.18it/s]
# ✅ Dataset berhasil didownload ke: d:\dhiya_skirpsi\model_YOLO11-seg\coffee-beans-dataset-2-(segmentation)-2
