# %%
from ultralytics import YOLO

model = YOLO("runs/segment/runs/coffee-seg/weights/best.pt")

metrics = model.val(data="dataset/data.yaml", split="val", plots=True)
# Out:
# Ultralytics 8.4.26  Python-3.14.3 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1660, 6144MiB)
# YOLO11n-seg summary (fused): 114 layers, 2,836,908 parameters, 0 gradients, 9.6 GFLOPs
# val: Fast image access  (ping: 5.95.8 ms, read: 1.20.5 MB/s, size: 12.7 KB)
# val: Scanning D:\dhiya_skirpsi\model_YOLO11-seg\dataset\valid\labels.cache... 2536 images, 12 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2536/2536 559.8Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 159/159 4.5it/s 35.6s0.2ss
#                    all       2536       3536      0.987       0.99       0.99      0.931      0.985      0.987      0.986      0.785
#                 broken        188        258      0.991      0.992      0.991      0.991      0.991      0.992      0.991      0.974
#         foreign_matter        710       1424      0.951      0.895      0.957      0.821      0.919      0.865      0.908      0.577
#             full_black        122        320      0.999          1      0.995      0.973      0.999          1      0.995      0.784
#              full_sour        188        188      0.987      0.989      0.988      0.934      0.987      0.989      0.988      0.757
#                 fungus        222        222      0.981          1      0.986      0.916      0.981          1      0.986      0.748
#                   good        160        160      0.997          1      0.995      0.975      0.997          1      0.995      0.893
#               immature        184        214      0.996          1      0.995      0.887      0.996          1      0.995      0.537
#          insect_severe        152        152      0.997          1      0.995      0.914      0.997          1      0.995      0.902
#          insect_slight        144        144      0.997          1      0.995      0.971      0.997          1      0.995      0.839
#          partial_black        184        184      0.998          1      0.995      0.954      0.998          1      0.995      0.856
#           partial_sour        124        124      0.982          1      0.995      0.932      0.982          1      0.995      0.893
#               withered        146        146      0.973          1      0.991      0.902      0.973          1      0.991      0.666
# Speed: 1.5ms preprocess, 7.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to D:\dhiya_skirpsi\model_YOLO11-seg\runs\segment\val2
